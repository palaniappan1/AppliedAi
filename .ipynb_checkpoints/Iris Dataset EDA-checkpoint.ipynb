# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings

iris = pd.read_csv("iris.csv")
print("To know how is the dataset:\n",iris.head(5))
print("Iris Shape:",iris.shape)
print("Iris Columns:",iris.columns)

#How many data points are present for each class ?
print("Value Count in iris dataset is: \n",iris["variety"].value_counts())
# Out:
# To know how is the dataset:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# Iris Shape: (150, 5)
# Iris Columns: Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')
# Value Count in iris dataset is:
#  Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# # 2-D Scatter Plot

# %%
iris.plot(kind="scatter",x = "sepal.length",y = "sepal.width")
plt.show()

# %% [markdown]
# # Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris,hue="variety",height=3) \
    .map(plt.scatter,"sepal.length","sepal.width") \
    .add_legend() 
# hue is basically color the points based on which data
#.map ==> #plot a scatter plot with x and y axis as given
#legend -> what color is what class label
#height -> size of the plot
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.set_style("whitegrid")
sns.pairplot(iris,hue = "variety", height = 3)
plt.show()
# Here we have 4 properties to compare(Petal and Sepal Length,Petal and Sepal width).So the permutation combinationn of 4C2 is 6 pairplots.
# Right and left side of the diagonal have 6 pairplots each which is the mirror image of each other.

# %% [markdown]
# # Histogram

# %%
iris_setosa = iris.loc[iris["variety"] == "Setosa"];
iris_virginica = iris.loc[iris["variety"] == "Virginica"];
iris_versicolor = iris.loc[iris["variety"] == "Versicolor"];

plt.plot(iris_setosa["petal.length"],np.zeros_like(iris_setosa["petal.length"]));
plt.plot(iris_versicolor["petal.length"],np.zeros_like(iris_versicolor["petal.length"]));
plt.plot(iris_virginica["petal.length"],np.zeros_like(iris_virginica["petal.length"]));

plt.xlabel("petal.length");
plt.show()

# %%
sns.FacetGrid(iris,hue="variety",height=6) \
   .map(sns.distplot,"petal.length") \
   .add_legend()

plt.show()

#Blue bar is the histogram of petal length of setosa flower
# x-axis is petal length and y-axis is count of number of datapoint within the given range
# The value 2.75 is the count of flowers with petal length 1.6
# The smooth curve is called the probablity density function
# Out:
# /Users/palaniappanmuthuraman/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/palaniappanmuthuraman/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Univariate Analysis

# %%
warnings.filterwarnings('ignore')
sns.FacetGrid(iris,hue = "variety", height = 5) \
    .map(sns.distplot,"sepal.length") \
    .add_legend()
plt.show()

sns.FacetGrid(iris,hue = "variety", height = 5) \
    .map(sns.distplot,"sepal.width") \
    .add_legend()
plt.show()

sns.FacetGrid(iris,hue = "variety", height = 5) \
    .map(sns.distplot,"petal.length") \
    .add_legend()
plt.show()

sns.FacetGrid(iris,hue = "variety", height = 5) \
    .map(sns.distplot,"petal.width") \
    .add_legend()
plt.show()


# PL > PW >> SL >> SW

# %% [markdown]
# # PDF (Probablity Denstiy functions)
#
# # CDF (Cumulative Distribution Function)

# %%
counts , bin_edges = np.histogram(iris_setosa['petal.length'],bins = 10, density = True)

print("Counts",counts)
pdf = counts / (sum(counts))
print("PDF",pdf)
print("Bin Edges",bin_edges)


#Compute CDF
cdf = np.cumsum(pdf)
#cumsum is cumulativesum
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

plt.show()
# Out:
# Counts [0.22222222 0.22222222 0.44444444 1.55555556 2.88888889 2.88888889
#  1.55555556 0.88888889 0.         0.44444444]
# PDF [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# Bin Edges [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
# import numpy as np

# consider you have an array like this

a= [1, 2, 3, 5, 10,11, 12, 13, 14, 15, 21,23, 25, 26, 27, 29, 30,31, 35, 51]

# here we have decided to group all these numbers into 5 bins

# i.e bins = 5

# the minimum number in the array is 1

# the maximum number in the array is 51

# the width of each bin is calculated as = ((max - min) / bins)

# width of each bin = (51-1)/5 = 10

# Since we got each bin with as 10, we can choose the bin edges like this

# 1 ...... 11 ....... 21 ........ 31 ....... 41 ....... 51

# |---10---|----10----|----10-----|----10----|----10----|

# so we have found out the bin edges now

# to find thte counts we calcuate how many number of points fall into each bin

# therefore the count of a bin = number of elements of a such that left_bin_egde<=ai 5 [1,2,3,5,10]

# ii. number of elements belongs to the 2nd bin 11<=x<21 => 5 [11,12,13,14,15]

# iii. number of elements belongs to the 3rd bin 21<=x<31 => 7 [21,23,25,26,27,29,30]

# iii. number of elements belongs to the 3rd bin 21<=x<31 => 7 [21,23,25,26,27,29,30]

# iv. number of elements belongs to the 4th bin 31<=x<41 => 2 [31,35]

# v. number of elements belongs to the 5th bin 41<=x<=51 => 1 [51]

# note: from the documentation: https://docs.scipy.org/doc/numpy/reference/generated/numpy.histogram.html

# All but the last (righthand-most) bin is half-open i.e [1,2,3,4], the bins are [1,2), [2,3), [3,4]

# [1,10) = 1,2,3,4,5,6,7,8,9 means includig 1 and but not 10. its half open bracket

print('='*30, "explaining 'bin edges and counts",'='*30)

counts,bins = np.histogram(a, bins=5)

print("bin edges :",bins)

print("counts per each bin :",counts)

# density: bool, optional

# If False, the result will contain the number of samples in each bin. 

# If True, the result is the value of the probability density function at the bin, normalized such that the integral over the range is 1. 

# Note that the sum of the histogram values will not be equal to 1 unless bins of unity width are chosen;

# it is not a probability mass function.

# and from the source code

#if density:

#        db = np.array(np.diff(bin_edges), float)

#        return n/db/n.sum(), bin_edges

# here the n => number of elements for each bin

n = counts

# and db = difference between bin edges

db = np.array(np.diff(bins))

# n.sum() number of all the elemnts 

print("db is ", db)

print('='*30, "explaining 'density=True' parameter",'='*30)

print("manual calculated densities for each bin",counts/db/counts.sum())

counts, bins = np.histogram(a, bins=5, density=True)

print("bin edges :",bins)

print("counts per each bin using density=True:",counts)

print('='*30, "explaining counts/sum(counts)",'='*30)

# pleasen note that the documentation says when you have density=True, 

# "that the sum of the histogram values will not be equal to 1"

# this is simple logic we used, to make the whole sum=1, we have divided each element by the number of whole elements

counts, bins = np.histogram(a, bins=5, density=True)

print("bin edges :",bins)

# sum(counts) = summ of all the elements in the counts array = [0.025 + 0.025 + 0.035 + 0.01 + 0.005] = 0.1

# counts/sum(counts) = devide every element of counts=[0.025/0.1, 0.025/0.1, 0.035/0.1, 0.01/0.1, 0.005/0.1] = [0.25 0.25 0.35 0.1  0.05]

print("counts per each bin using density=True:",counts/sum(counts))

# The output of this above program

# ============================== explaining 'bin edges and counts ==============================

# bin edges : [ 1. 11. 21. 31. 41. 51.]

# counts per each bin : [5 5 7 2 1]

# ============================== explaining 'density=True' parameter ==============================

# manual calculated densities for each bin [0.025 0.025 0.035 0.01  0.005]

# bin edges : [ 1. 11. 21. 31. 41. 51.]

# counts per each bin using density=True: [0.025 0.025 0.035 0.01  0.005]

# ============================== explaining counts/sum(counts) ==============================

# bin edges : [ 1. 11. 21. 31. 41. 51.]

# counts per each bin using density=True: [0.25 0.25 0.35 0.1  0.05]
# Out:
# ============================== explaining 'bin edges and counts ==============================
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin : [5 5 7 2 1]
# db is  [10. 10. 10. 10. 10.]
# ============================== explaining 'density=True' parameter ==============================
# manual calculated densities for each bin [0.025 0.025 0.035 0.01  0.005]
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin using density=True: [0.025 0.025 0.035 0.01  0.005]
# ============================== explaining counts/sum(counts) ==============================
# bin edges : [ 1. 11. 21. 31. 41. 51.]
# counts per each bin using density=True: [0.25 0.25 0.35 0.1  0.05]

# %% [markdown]
# # CDF of petal length of various types of fowers

# %%
counts, bin_edges = np.histogram(iris_setosa['petal.length'],bins = 10, density = True)

pdf = counts/ sum(counts)
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

counts, bin_edges = np.histogram(iris_virginica['petal.length'],bins = 10, density = True)

pdf = counts/ sum(counts)
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)


counts, bin_edges = np.histogram(iris_versicolor['petal.length'],bins = 10, density = True)

pdf = counts/ sum(counts)
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
# Out:
# [0.02 0.02 0.04 0.14 0.26 0.26 0.14 0.08 0.   0.04]
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]
# [0.02 0.1  0.24 0.08 0.18 0.16 0.1  0.04 0.02 0.06]
# [4.5  4.74 4.98 5.22 5.46 5.7  5.94 6.18 6.42 6.66 6.9 ]
# [0.02 0.04 0.06 0.04 0.16 0.14 0.12 0.2  0.14 0.08]
# [3.   3.21 3.42 3.63 3.84 4.05 4.26 4.47 4.68 4.89 5.1 ]

# %% [markdown]
# # Mean

# %%
print("Mean")
print("of Setosa Petal Length: ", np.mean([iris_setosa["petal.length"]]))
print("Mean of Setosa Petal Length with outlier value:", np.mean(np.append(iris_setosa["petal.length"],50)))
print("of Virginica Petal Length: ", np.mean([iris_virginica["petal.length"]]))
print("of Versicolor Petal Length: ", np.mean([iris_versicolor["petal.length"]]))
#An outlier is an observation that lies an abnormal distance from other values in a random sample from a population
# Out:
# Mean
# of Setosa Petal Length:  1.4620000000000002
# Mean of Setosa Petal Length with outlier value: 2.4137254901960787
# of Virginica Petal Length:  5.5520000000000005
# of Versicolor Petal Length:  4.26

# %% [markdown]
# # Standard Deviation

# %%
print("Standard Deviation")
print("of Setosa Petal Length: ", np.std([iris_setosa["petal.length"]]))
print("of Virginica Petal Length: ", np.std([iris_virginica["petal.length"]]))
print("of Versicolor Petal Length: ", np.std([iris_versicolor["petal.length"]]))
# Out:
# Standard Deviation
# of Setosa Petal Length:  0.17191858538273283
# of Virginica Petal Length:  0.546347874526844
# of Versicolor Petal Length:  0.4651881339845203

# %% [markdown]
# # Median

# %%
print("Median")
print("of Setosa Petal Length: ", np.median([iris_setosa["petal.length"]]))
print("Mean of Setosa Petal Length with outlier value:", np.median(np.append(iris_setosa["petal.length"],50)))
print("of Virginica Petal Length: ", np.median([iris_virginica["petal.length"]]))
print("of Versicolor Petal Length: ", np.median([iris_versicolor["petal.length"]]))
# Out:
# Median
# of Setosa Petal Length:  1.5
# Mean of Setosa Petal Length with outlier value: 1.5
# of Virginica Petal Length:  5.55
# of Versicolor Petal Length:  4.35

# %% [markdown]
# # Quantiles

# %%
print("Quatiles")
print("of Setosa Petal Length: ", np.percentile([iris_setosa["petal.length"]],np.arange(0,100,25)))
print("of Virginica Petal Length: ", np.percentile([iris_virginica["petal.length"]],np.arange(0,100,25)))
print("of Versicolor Petal Length: ", np.percentile([iris_versicolor["petal.length"]],np.arange(0,100,25)))

#See 90th percentile
print("\n90th percentile")
print("of Setosa Petal Length: ", np.percentile([iris_setosa["petal.length"]],90))
print("of Virginica Petal Length: ", np.percentile([iris_virginica["petal.length"]],90))
print("of Versicolor Petal Length: ", np.percentile([iris_versicolor["petal.length"]],90))
# Out:
# Quatiles
# of Setosa Petal Length:  [1.    1.4   1.5   1.575]
# of Virginica Petal Length:  [4.5   5.1   5.55  5.875]
# of Versicolor Petal Length:  [3.   4.   4.35 4.6 ]
#
# 90th percentile
# of Setosa Petal Length:  1.7
# of Virginica Petal Length:  6.31
# of Versicolor Petal Length:  4.8

# %% [markdown]
# # Median Absolute Deviation

# %%
from statsmodels import robust
print("Median Absolute Deviation")
print(robust.mad(iris_setosa["petal.length"]))
print(robust.mad(iris_virginica["petal.length"]))
print(robust.mad(iris_versicolor["petal.length"]))
# Out:
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # Box Plot and Whiskers

# %%
sns.boxplot(x="variety",y="petal.length",data=iris)
plt.show()

#Whiskers can be drawn by using min an max values
#But seaborn does not use min and max in drawing whiskers.It uses 1.5 * IQR.
#Seaborn uses some complex mechanism to draw whiskers that is why the virginica whiskers above and below are different
#There is no standard way to draw whiskers

# %% [markdown]
# # Violin Plots

# %%
# Violin Plot cobines the benefits of Boxplot and histogram & PDF 
sns.violinplot(x = "variety",y = "petal.length",data=iris,height=8)
plt.show()

# %%
# 2-D Density Plot
sns.jointplot(x = "petal.length", y= "petal.width" , data = iris_setosa,kind="kde")
plt.show()

# %% [markdown]
# # Q-Q Plot

# %%
import numpy as np
import pylab
import scipy.stats as stats

# N(0,1)
std_normal = np.random.normal(loc = 0, scale = 1, size = 1000)
# Generate samples randomly from a gaussian disb with mean 0 and s.d 1 and 1000 such samples. (Generate random observations )

# 0 to 100th percentiles of std-normal
for i in range(0,101):
    print(i, np.percentile(std_normal,i))
    
stats.probplot(std_normal, dist = "norm", plot = pylab)
pylab.show()
# Out:
# 0 -3.126342433613618
# 1 -1.9951530937187476
# 2 -1.9113195781564611
# 3 -1.7830406265728016
# 4 -1.6741483916628142
# 5 -1.5963756361267198
# 6 -1.5248514476744086
# 7 -1.4771296307068766
# 8 -1.3808466154406192
# 9 -1.3301233481253794
# 10 -1.2478301811430277
# 11 -1.1892952220344006
# 12 -1.1424618263687163
# 13 -1.0974290810658276
# 14 -1.0555805741690403
# 15 -1.0256531365375317
# 16 -0.9966200881904692
# 17 -0.9700138323633176
# 18 -0.9242492481536745
# 19 -0.8987829876149853
# 20 -0.8646786538192534
# 21 -0.8391459022371401
# 22 -0.8147865910715003
# 23 -0.783687148239658
# 24 -0.7683185569051462
# 25 -0.7325990031287527
# 26 -0.6750364769159043
# 27 -0.6464742503103347
# 28 -0.6114031409325934
# 29 -0.590914513536909
# 30 -0.5559090552216108
# 31 -0.5253134663091513
# 32 -0.49851282813345765
# 33 -0.47891502630205235
# 34 -0.458976085649917
# 35 -0.4364776090864049
# 36 -0.41633759477522925
# 37 -0.4024615056660651
# 38 -0.3801967208411318
# 39 -0.3506833155486942
# ...

# %%
# generate 100 samples from N(0,25)
measurements = np.random.normal(loc = 20, scale = 5, size = 1000)
#If size 100,, there are many points outside the line, in size 1000 only the extremes are tend to be outside 
#else most points lies in the straight line
#As we can understand, as the sample size increases more poits are on line.So the limitation of Q-Q plots is 
#less the number of samples it is hard to interpret

stats.probplot(measurements, dist = "norm", plot = pylab)
#probplot = Probablity plot, dist = "norm" tells compare it with N(0,1) and plot using library pylab
pylab.show()

# %%
measurements = np.random.uniform(low = -1, high = 1, size = 10000)
# X-axis is gaussian disb and Y-axis is unifrom disb
stats.probplot(measurements, dist = "norm", plot = pylab)
pylab.show()

#If all points lie on the straight line then you can conclude that the disb on x and y axis are of the same family
